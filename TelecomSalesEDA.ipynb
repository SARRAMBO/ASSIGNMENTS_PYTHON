# %% [markdown]
# <a href="https://colab.research.google.com/github/SARRAMBO/ASSIGNMENTS_PYTHON/blob/main/TelecomSalesEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#FETCH DATA-
df = pd.read_csv("/telecom_data.csv")
print(df)
# Out:
#              Alliance Partner Division  Alliance Partner Division Code  \
# 0                           7-11 - AUS                             656
# 1                           7-11 - AUS                             656
# 2                           7-11 - AUS                             656
# 3                           7-11 - AUS                             656
# 4                           7-11 - AUS                             656
# ...                                ...                             ...
# 206614  WOOLWORTHS GROCERY - AUSTRALIA                            1052
# 206615  WOOLWORTHS GROCERY - AUSTRALIA                            1052
# 206616  WOOLWORTHS GROCERY - AUSTRALIA                            1052
# 206617  WOOLWORTHS GROCERY - AUSTRALIA                            1052
# 206618  WOOLWORTHS GROCERY - AUSTRALIA                            1052
#
#        Card Partner Division                          Product  \
# ...

# %%
#column info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206619 entries, 0 to 206618
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Alliance Partner Division       206619 non-null  object
#  1   Alliance Partner Division Code  206619 non-null  int64
#  2   Card Partner Division           206619 non-null  object
#  3   Product                         206619 non-null  object
#  4   Store                           206619 non-null  object
#  5   Store Code                      206619 non-null  object
#  6   Date                            206619 non-null  object
#  7   Fiscal Week                     206619 non-null  int64
#  8   Month                           206619 non-null  int64
#  9   Fiscal Year                     206619 non-null  int64
#  10  Sales Units                     206619 non-null  int64
#  11  Sales Amount-Non USD            206619 non-null  object
# ...

# %%
#obtaining numerical columns info-
df.describe()
#obtaining categorical columns info-
df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#              Alliance Partner Division Card Partner Division  \
# count                           206619                206619
# unique                              12                     2
# top     WOOLWORTHS GROCERY - AUSTRALIA          VODAFONE SIM
# freq                             85117                147109
#
#                                Product                       Store Store Code  \
# count                           206619                      206619     206619
# unique                              21                        5862       9401
# top     VODAFONE SIM TRIPLE PUNCH 2AUD  Coles World Square - 00710      92007
# freq                             27863                        1005        627
#
#             Date Sales Amount-Non USD   month
# count     206619               206619  206619
# unique       224                  245       8
# top     4-8-2023                2.00     July
# freq        1124                46560   30586

# %%
df.dtypes
df["revenue"] =df["Sales Units"]*df["Sales Amount-Non USD"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51d2338cb23e> in <cell line: 1>()
# ----> 1 df.dtypes
#       2 df["revenue"] =df["Sales Units"]*df["Sales Amount-Non USD"]
#
# NameError: name 'df' is not defined
